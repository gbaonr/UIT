# %%
import pandas as pd

# %%
tkan_df = pd.read_csv("tkan_results.csv")
gru_df = pd.read_csv("gru_results_all_runs.csv")    
tkan_df['run'] = tkan_df['run'].astype(int) + 1

# %%
print(tkan_df['mae'].mean())
print(gru_df['mae'].mean())
print(tkan_df['mape'].mean())
print(gru_df['mape'].mean()/100)
# Out:
# 6.3548707718047925
# 6.044357174496639
# 19.0878502563853
# 18.158724922713635
